# %% [markdown]
# # Activity 1: Data Science with Google Colab
# ### eMathrix Education — Data Science & Data Analytics
#
# **▶ Step 1 (do this first, before any code):** answer the **class intake form** — it collects your identity and a
# quick prior-knowledge check: **https://forms.gle/Z2AJpKTMx5CZcdFq7** (opens in a new tab).
# Pagkatapos ninyong sagutan ang intake form, saka kayo magpatuloy sa Colab sa ibaba.
#
# In this activity you will then connect **your own Google Form survey** to Colab and turn your responses into charts.
#
# **The flow today:**
# 1. **Answer the class intake form** (link above) ← Step 1
# 2. Make a short Google Form of your own (with linked Sheet)
# 3. Get a few responses
# 4. Copy your Sheet ID
# 5. Connect Colab to your Sheet
# 6. Build charts from your own data
#
# Run each cell by clicking it and pressing **Shift + Enter**. Go in order, top to bottom.

# %% [markdown]
# ---
# ## Before you touch any code: make your form
#
# 1. Go to **forms.google.com** and create a new form. Keep it short, 4 to 6 questions, mostly multiple choice.
# 2. In the form, click the **Responses** tab, then the green Sheets icon, then **Create spreadsheet**. This links a Google Sheet that fills automatically.
# 3. **Important:** fill out your own form 5 or 6 times so you have data to chart. No responses means empty charts later. Pwede rin kayong mag-sagutan ng katabi nyo.
# 4. Make sure the Google account you use here in Colab is the **same account that owns the form.** Magkaiba ang account, hindi gagana ang koneksyon.

# %% [markdown]
# ---
# ## Get your Sheet ID
#
# Open your linked Google Sheet. Look at the address bar. The URL looks like this:
#
# `https://docs.google.com/spreadsheets/d/`**`1AbCdEfGhIjKlMnOpQrStUvWxYz1234567890`**`/edit`
#
# The **bold part between `/d/` and `/edit`** is your Sheet ID. Copy it. You'll paste it in Step 4.
#
# > **Important — this is just an example.** The ID above (`1AbCdEfGhIjKlMnOpQrStUvWxYz1234567890`) is a fake placeholder, only to show you what a Sheet ID looks like. It will **not** work. Once you're working on your own, you **must** replace it with the ID from **your own** Google Sheet, signed in with **your own** Google account that owns the form.
# >
# > Halimbawa lang ito. Palitan nyo ng sarili nyong Sheet ID at gamitin ang sarili nyong Google account kapag kayo na ang gagawa.

# %% [markdown]
# ---
# ## Step 1: Install the tools
#
# This installs the libraries that let Colab talk to Google Sheets. Run it once.

# %%
# !pip install gspread google-auth
# Out:
# Requirement already satisfied: gspread in /usr/local/lib/python3.12/dist-packages (6.2.1)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.12/dist-packages (2.49.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from gspread) (1.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth) (49.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth) (4.9.1)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth) (2.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth) (3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2026.6.17)

# %% [markdown]
# ## Step 2: Load the libraries
#
# This brings in pandas (for tables), matplotlib (for charts), and the Google connection tools.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import gspread
from google.auth import default
from google.colab import auth

print("Setup complete!")
# Out:
# Setup complete!

# %% [markdown]
# ## Step 3: Log in to Google
#
# **Heads up before you run this:** a popup will appear asking you to choose your Google account and allow access.
#
# - Pick **your own** Google account — the one that **owns your form**. During class, do **not** use the trainer's example account; sign in as yourself.
# - Click through every **Allow** / **Continue** screen.
# - The popup sometimes hides behind this window or gets blocked. If nothing happens, check for a blocked-popup icon in your address bar, or look behind the browser window.
#
# Tandaan: sariling account nyo ang gamitin, hindi ang account ng trainer.

# %%
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

print("Connected to Google!")
print("Ready to open your Google Sheet.")
# Out:
# Connected to Google!
# Ready to open your Google Sheet.

# %% [markdown]
# ## Step 4: Connect to YOUR sheet
#
# Replace the placeholder below with your **own** Sheet ID (the one you copied earlier), then run the cell.
#
# The starting value `PASTE_YOUR_SHEET_ID_HERE` is **just a placeholder** — it will fail on purpose until you swap in your real ID. We set the ID **once here** and reuse it for the rest of the notebook, so you only paste it in one place.

# %%
# ==== PASTE YOUR OWN SHEET ID BETWEEN THE QUOTES ====
SHEET_ID = "1VSw0y0fsMOam3nonKGydjeHmlaVPJ7Hrb7ZuiWQc63U"
# =====================================================

# Connect and pull the data once
try:
    sheet = gc.open_by_key(SHEET_ID).get_worksheet(0)
    data = sheet.get_all_values()

    if len(data) > 1:
        df = pd.DataFrame(data[1:], columns=data[0])
        print(f"SUCCESS! Connected to your survey.")
        print(f"Responses found: {len(df)}")
        print(f"Questions (columns): {len(df.columns)}")
        print("\nYour questions:")
        for i, col in enumerate(df.columns):
            short = col[:60] + "..." if len(col) > 60 else col
            print(f"  Column {i}: {short}")
    else:
        print("Connected, but no responses yet.")
        print("Go fill out your form a few times, then run this cell again.")

except Exception as e:
    print(f"Connection failed: {e}")
    print("\nCheck these:")
    print("1. Is your SHEET_ID pasted correctly (no extra spaces)?")
    print("2. Are you logged in with the account that owns the form?")
    print("3. Did you run Step 3 first?")
# Out:
# SUCCESS! Connected to your survey.
# Responses found: 32
# Questions (columns): 11
#
# Your questions:
#   Column 0: Timestamp
#   Column 1: Which operating system do you know how to navigate best?
#   Column 2: How would you rate your overall comfort level when using a c...
#   Column 3: Rate your proficiency level for each of the following everyd...
#   Column 4: Rate your proficiency level for each of the following everyd...
#   Column 5: Rate your proficiency level for each of the following everyd...
#   Column 6: Rate your proficiency level for each of the following everyd...
#   Column 7: Rate your proficiency level for each of the following everyd...
#   Column 8: If your computer suddenly loses internet connectivity, what ...
#   Column 9: How do you handle software or operating system updates?
#   Column 10: Which basic IT topic would you be most interested in learnin...

# %% [markdown]
# ## Step 5: See your full data table
#
# This shows everything you collected as a clean table. The **Column** numbers shown above are what you'll use to pick which question to chart.

# %%
if len(data) > 1:
    print(f"Rows (responses): {len(df)}")
    print(f"Columns (questions): {len(df.columns)}")
    print("\nYour complete data:")
    from IPython.display import display
    display(df)
else:
    print("No responses yet. Fill out your form first, then re-run Step 4.")
# Out:
# Rows (responses): 32
# Columns (questions): 11
#
# Your complete data:
#              Timestamp  \
# 0   7/13/2026 16:09:32
# 1   7/13/2026 16:10:50
# 2   7/13/2026 16:22:21
# 3   7/13/2026 16:28:46
# 4   7/13/2026 16:42:15
# 5   7/13/2026 16:42:35
# 6   7/13/2026 16:42:44
# 7   7/13/2026 16:42:48
# 8   7/13/2026 16:43:35
# 9   7/13/2026 16:45:32
# 10  7/13/2026 16:46:43
# 11  7/13/2026 16:47:01
# 12  7/13/2026 16:49:03
# 13  7/13/2026 16:49:19
# 14  7/13/2026 16:52:38
# 15  7/13/2026 16:58:17
# 16  7/13/2026 17:01:12
# 17  7/13/2026 17:04:20
# 18  7/13/2026 17:06:37
# 19  7/13/2026 17:11:03
# 20  7/13/2026 17:12:20
# 21  7/13/2026 17:16:04
# 22  7/13/2026 17:22:47
# 23  7/13/2026 17:26:35
# 24  7/13/2026 17:27:08
# 25  7/13/2026 17:29:07
# 26  7/13/2026 17:32:19
# 27  7/13/2026 17:50:24
# 28  7/13/2026 17:59:11
# 29  7/13/2026 18:06:22
# 30  7/13/2026 23:44:49
# 31  7/13/2026 23:59:27
#
#    Which operating system do you know how to navigate best?   \
# 0                                             Windows
# 1                                             Windows
# 2                                             Windows
# 3                                             Windows
# 4                                             Windows
# 5                                             Windows
# 6                                             Windows
# 7                                             Windows
# 8                                             Windows
# 9                                             Windows
# 10                                            Windows
# 11                                            Windows
# 12                                            Windows
# 13                                            Windows
# 14                                            Windows
# 15                                            Windows
# 16                                            Windows
# 17                                            Windows
# 18                                            Windows
# 19                                            Windows
# 20                                            Windows
# 21                                            Windows
# 22                                            Windows
# 23                                            Windows
# 24                                            Windows
# 25                                            Windows
# 26                                            Windows
# 27                                            Windows
# 28                                            Windows
# 29                                            Windows
# 30                                            Windows
# 31                                            Windows
#
#    How would you rate your overall comfort level when using a computer or laptop?    \
# 0   I can browse the web and check email, but ofte...
# 1   I feel confident trying new programs, managing...
# 2   I can browse the web and check email, but ofte...
# 3   I easily navigate software, manage files, and ...
# 4   I easily navigate software, manage files, and ...
# 5   I easily navigate software, manage files, and ...
# 6   I can browse the web and check email, but ofte...
# 7   I can browse the web and check email, but ofte...
# 8   I can browse the web and check email, but ofte...
# 9   I feel confident trying new programs, managing...
# 10  I easily navigate software, manage files, and ...
# 11  I can browse the web and check email, but ofte...
# 12  I can browse the web and check email, but ofte...
# 13  I feel confident trying new programs, managing...
# 14  I feel confident trying new programs, managing...
# 15  I feel confident trying new programs, managing...
# 16  I easily navigate software, manage files, and ...
# 17  I easily navigate software, manage files, and ...
# 18  I can browse the web and check email, but ofte...
# 19  I easily navigate software, manage files, and ...
# 20  I can browse the web and check email, but ofte...
# 21  I easily navigate software, manage files, and ...
# 22  I can browse the web and check email, but ofte...
# 23  I easily navigate software, manage files, and ...
# 24  I can browse the web and check email, but ofte...
# 25  I can browse the web and check email, but ofte...
# 26  I easily navigate software, manage files, and ...
# 27  I easily navigate software, manage files, and ...
# 28  I feel confident trying new programs, managing...
# 29  I feel confident trying new programs, managing...
# 30  I can browse the web and check email, but ofte...
# 31  I can browse the web and check email, but ofte...
#
#    Rate your proficiency level for each of the following everyday tasks:   [File Management (Creating folders, zipping files, organizing downloads)]  \
# 0                         Medium (Can do with effort)
# 1                             High (Confident & Fast)
# 2                         Medium (Can do with effort)
# 3                             High (Confident & Fast)
# 4                             High (Confident & Fast)
# 5                             High (Confident & Fast)
# 6                         Medium (Can do with effort)
# 7                            Low (Struggle with this)
# 8                         Medium (Can do with effort)
# 9                             High (Confident & Fast)
# 10                            High (Confident & Fast)
# 11                           Low (Struggle with this)
# 12                            High (Confident & Fast)
# 13                            High (Confident & Fast)
# 14                        Medium (Can do with effort)
# 15                            High (Confident & Fast)
# 16                            High (Confident & Fast)
# 17                            High (Confident & Fast)
# 18                            High (Confident & Fast)
# 19                            High (Confident & Fast)
# 20                        Medium (Can do with effort)
# 21                            High (Confident & Fast)
# 22                        Medium (Can do with effort)
# 23                        Medium (Can do with effort)
# 24                            High (Confident & Fast)
# 25                            High (Confident & Fast)
# 26                            High (Confident & Fast)
# 27                            High (Confident & Fast)
# 28                            High (Confident & Fast)
# 29                            High (Confident & Fast)
# 30                        Medium (Can do with effort)
# 31                        Medium (Can do with effort)
#
#    Rate your proficiency level for each of the following everyday tasks:   [Word Processing (Typing documents, basic formatting, saving as PDF)]  \
# 0                         Medium (Can do with effort)
# 1                             High (Confident & Fast)
# 2                         Medium (Can do with effort)
# 3                             High (Confident & Fast)
# 4                         Medium (Can do with effort)
# 5                             High (Confident & Fast)
# 6                         Medium (Can do with effort)
# 7                         Medium (Can do with effort)
# 8                         Medium (Can do with effort)
# 9                             High (Confident & Fast)
# 10                            High (Confident & Fast)
# 11                           Low (Struggle with this)
# 12                        Medium (Can do with effort)
# 13                            High (Confident & Fast)
# 14                        Medium (Can do with effort)
# 15                            High (Confident & Fast)
# 16                            High (Confident & Fast)
# 17                            High (Confident & Fast)
# 18                            High (Confident & Fast)
# 19                            High (Confident & Fast)
# 20                        Medium (Can do with effort)
# 21                            High (Confident & Fast)
# 22                        Medium (Can do with effort)
# 23                            High (Confident & Fast)
# 24                            High (Confident & Fast)
# 25                            High (Confident & Fast)
# 26                            High (Confident & Fast)
# 27                            High (Confident & Fast)
# 28                            High (Confident & Fast)
# 29                            High (Confident & Fast)
# 30                        Medium (Can do with effort)
# 31                        Medium (Can do with effort)
#
#    Rate your proficiency level for each of the following everyday tasks:   [Spreadsheets (Entering data, basic sorting, using simple formulas)]  \
# 0                         Medium (Can do with effort)
# 1                             High (Confident & Fast)
# 2                         Medium (Can do with effort)
# 3                             High (Confident & Fast)
# 4                         Medium (Can do with effort)
# 5                         Medium (Can do with effort)
# 6                         Medium (Can do with effort)
# 7                            Low (Struggle with this)
# 8                         Medium (Can do with effort)
# 9                             High (Confident & Fast)
# 10                            High (Confident & Fast)
# 11                        Medium (Can do with effort)
# 12                        Medium (Can do with effort)
# 13                            High (Confident & Fast)
# 14                        Medium (Can do with effort)
# 15                            High (Confident & Fast)
# 16                        Medium (Can do with effort)
# 17                            High (Confident & Fast)
# 18                            High (Confident & Fast)
# 19                            High (Confident & Fast)
# 20                        Medium (Can do with effort)
# 21                        Medium (Can do with effort)
# 22                            High (Confident & Fast)
# 23                        Medium (Can do with effort)
# 24                            High (Confident & Fast)
# 25                            High (Confident & Fast)
# 26                            High (Confident & Fast)
# 27                            High (Confident & Fast)
# 28                            High (Confident & Fast)
# 29                        Medium (Can do with effort)
# 30                        Medium (Can do with effort)
# 31                        Medium (Can do with effort)
#
#    Rate your proficiency level for each of the following everyday tasks:   [Web Browsing & Safety (Bookmarking, clearing cache, spotting suspicious links)]  \
# 0                         Medium (Can do with effort)
# 1                             High (Confident & Fast)
# 2
# 3                             High (Confident & Fast)
# 4                         Medium (Can do with effort)
# 5                             High (Confident & Fast)
# 6                         Medium (Can do with effort)
# 7                            Low (Struggle with this)
# 8                         Medium (Can do with effort)
# 9                             High (Confident & Fast)
# 10
# 11                        Medium (Can do with effort)
# 12                            High (Confident & Fast)
# 13                            High (Confident & Fast)
# 14                        Medium (Can do with effort)
# 15                            High (Confident & Fast)
# 16                            High (Confident & Fast)
# 17                            High (Confident & Fast)
# 18                            High (Confident & Fast)
# 19                            High (Confident & Fast)
# 20                        Medium (Can do with effort)
# 21                            High (Confident & Fast)
# 22                            High (Confident & Fast)
# 23                            High (Confident & Fast)
# 24                            High (Confident & Fast)
# 25                            High (Confident & Fast)
# 26                            High (Confident & Fast)
# 27                            High (Confident & Fast)
# 28                            High (Confident & Fast)
# 29                            High (Confident & Fast)
# 30                            High (Confident & Fast)
# 31                        Medium (Can do with effort)
#
#    Rate your proficiency level for each of the following everyday tasks:   [Cloud Storage (Uploading/sharing files on Google Drive or OneDrive)]  \
# 0                         Medium (Can do with effort)
# 1                             High (Confident & Fast)
# 2                         Medium (Can do with effort)
# 3                             High (Confident & Fast)
# 4                         Medium (Can do with effort)
# 5                             High (Confident & Fast)
# 6                         Medium (Can do with effort)
# 7                         Medium (Can do with effort)
# 8                         Medium (Can do with effort)
# 9                             High (Confident & Fast)
# 10                        Medium (Can do with effort)
# 11                           Low (Struggle with this)
# 12                            High (Confident & Fast)
# 13                            High (Confident & Fast)
# 14                        Medium (Can do with effort)
# 15                            High (Confident & Fast)
# 16                            High (Confident & Fast)
# 17
# 18                            High (Confident & Fast)
# 19                            High (Confident & Fast)
# 20                        Medium (Can do with effort)
# 21                        Medium (Can do with effort)
# 22                            High (Confident & Fast)
# 23                        Medium (Can do with effort)
# 24                            High (Confident & Fast)
# 25                            High (Confident & Fast)
# 26                            High (Confident & Fast)
# 27                            High (Confident & Fast)
# 28                            High (Confident & Fast)
# 29                            High (Confident & Fast)
# 30                        Medium (Can do with effort)
# 31                        Medium (Can do with effort)
#
#    If your computer suddenly loses internet connectivity, what is the first thing you typically do?    \
# 0   Restart the computer or toggle the Wi-Fi setti...
# 1   Restart the computer or toggle the Wi-Fi setti...
# 2             Call for technical support immediately.
# 3   Check the physical router/modem cables and sta...
# 4   Restart the computer or toggle the Wi-Fi setti...
# 5   Restart the computer or toggle the Wi-Fi setti...
# 6   Restart the computer or toggle the Wi-Fi setti...
# 7             Call for technical support immediately.
# 8             Call for technical support immediately.
# 9   Restart the computer or toggle the Wi-Fi setti...
# 10  Restart the computer or toggle the Wi-Fi setti...
# 11  Restart the computer or toggle the Wi-Fi setti...
# 12  Check the physical router/modem cables and sta...
# 13  Check the physical router/modem cables and sta...
# 14  Check the physical router/modem cables and sta...
# 15  Check the physical router/modem cables and sta...
# 16  Check the physical router/modem cables and sta...
# 17            Call for technical support immediately.
# 18            Call for technical support immediately.
# 19  Restart the computer or toggle the Wi-Fi setti...
# 20            Call for technical support immediately.
# 21  Restart the computer or toggle the Wi-Fi setti...
# 22  Restart the computer or toggle the Wi-Fi setti...
# 23  Restart the computer or toggle the Wi-Fi setti...
# 24  Check the physical router/modem cables and sta...
# 25  Restart the computer or toggle the Wi-Fi setti...
# 26  Restart the computer or toggle the Wi-Fi setti...
# 27  Restart the computer or toggle the Wi-Fi setti...
# 28  Restart the computer or toggle the Wi-Fi setti...
# 29  Restart the computer or toggle the Wi-Fi setti...
# 30  Restart the computer or toggle the Wi-Fi setti...
# 31            Call for technical support immediately.
#
#    How do you handle software or operating system updates?    \
# 0   I actively ignore or postpone them because I'm...
# 1   I regularly update my software to stay secure ...
# 2   I actively ignore or postpone them because I'm...
# 3   I regularly update my software to stay secure ...
# 4   I regularly update my software to stay secure ...
# 5   I install them only when the system forces me ...
# 6   I actively ignore or postpone them because I'm...
# 7   I actively ignore or postpone them because I'm...
# 8   I actively ignore or postpone them because I'm...
# 9   I install them only when the system forces me ...
# 10  I install them only when the system forces me ...
# 11  I actively ignore or postpone them because I'm...
# 12  I regularly update my software to stay secure ...
# 13  I regularly update my software to stay secure ...
# 14  I actively ignore or postpone them because I'm...
# 15  I actively ignore or postpone them because I'm...
# 16  I regularly update my software to stay secure ...
# 17  I install them only when the system forces me ...
# 18  I actively ignore or postpone them because I'm...
# 19  I regularly update my software to stay secure ...
# 20  I actively ignore or postpone them because I'm...
# 21  I install them only when the system forces me ...
# 22  I regularly update my software to stay secure ...
# 23  I regularly update my software to stay secure ...
# 24  I regularly update my software to stay secure ...
# 25  I regularly update my software to stay secure ...
# 26  I actively ignore or postpone them because I'm...
# 27  I regularly update my software to stay secure ...
# 28  I install them only when the system forces me ...
# 29  I install them only when the system forces me ...
# 30  I actively ignore or postpone them because I'm...
# 31  I install them only when the system forces me ...
#
#    Which basic IT topic would you be most interested in learning more about?
# 0   Data organization and spreadsheet basics (Exce...
# 1   Keyboard shortcuts and operating system naviga...
# 2   Digital security, password managers, and priva...
# 3   Understanding hardware specs (RAM, CPU, storag...
# 4   Understanding hardware specs (RAM, CPU, storag...
# 5   Digital security, password managers, and priva...
# 6   Digital security, password managers, and priva...
# 7   Keyboard shortcuts and operating system naviga...
# 8   Data organization and spreadsheet basics (Exce...
# 9   Digital security, password managers, and priva...
# 10  Data organization and spreadsheet basics (Exce...
# 11  Keyboard shortcuts and operating system naviga...
# 12  Digital security, password managers, and priva...
# 13  Digital security, password managers, and priva...
# 14  Understanding hardware specs (RAM, CPU, storag...
# 15  Understanding hardware specs (RAM, CPU, storag...
# 16  Digital security, password managers, and priva...
# 17  Digital security, password managers, and priva...
# 18  Keyboard shortcuts and operating system naviga...
# 19  Digital security, password managers, and priva...
# 20  Digital security, password managers, and priva...
# 21  Keyboard shortcuts and operating system naviga...
# 22  Data organization and spreadsheet basics (Exce...
# 23  Data organization and spreadsheet basics (Exce...
# 24  Understanding hardware specs (RAM, CPU, storag...
# 25  Keyboard shortcuts and operating system naviga...
# 26  Understanding hardware specs (RAM, CPU, storag...
# 27  Digital security, password managers, and priva...
# 28  Digital security, password managers, and priva...
# 29  Digital security, password managers, and priva...
# 30  Understanding hardware specs (RAM, CPU, storag...
# 31  Keyboard shortcuts and operating system naviga...

# %% [markdown]
# ## Step 6: Bar chart of one question
#
# A bar chart counts how many people picked each answer. Change the **`question_column`** number to look at a different question. Look at your column list from Step 4 to pick the number.

# %%
question_column = 7   # change this number to chart a different question

if len(data) > 1 and question_column < len(df.columns):
    question_name = df.columns[question_column]
    answer_counts = df.iloc[:, question_column].value_counts()

    print(f"Bar chart for: {question_name}")

    plt.figure(figsize=(12, 6))
    bars = plt.bar(answer_counts.index.astype(str), answer_counts.values)

    for bar, count in zip(bars, answer_counts.values):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.05,
                 str(count), ha='center', va='bottom', fontweight='bold')

    plt.title(f'{question_name}', fontsize=14, fontweight='bold')
    plt.xlabel('Answers')
    plt.ylabel('Number of people')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()

    print(f"Most popular answer: '{answer_counts.index[0]}' ({answer_counts.iloc[0]} people)")
else:
    print("No data, or that question number does not exist. Check Step 4.")
# Out:
# Bar chart for: Rate your proficiency level for each of the following everyday tasks:   [Cloud Storage (Uploading/sharing files on Google Drive or OneDrive)]
# Most popular answer: 'High (Confident & Fast)' (17 people)

# %% [markdown]
# **Notice:** the only thing you changed to chart a different question was the number in `question_column`. That's the whole trick. Try changing it to 2, then re-run this cell.

# %% [markdown]
# ## Step 7: Pie chart of one question
#
# A pie chart shows the same counts as percentages of the whole. Same idea, change `question_column` to pick a question.

# %%
question_column = 2   # change this number to chart a different question

if len(data) > 1 and question_column < len(df.columns):
    question_name = df.columns[question_column]
    answer_counts = df.iloc[:, question_column].value_counts()

    print(f"Pie chart for: {question_name}")

    plt.figure(figsize=(8, 6))
    plt.pie(answer_counts.values,
            labels=answer_counts.index.astype(str),
            autopct=lambda p: f'{p:.0f}%\n({int(round(p*answer_counts.sum()/100))})',
            startangle=90)
    plt.title(f'{question_name}', fontsize=14, fontweight='bold')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()

    print(f"Most people answered: '{answer_counts.index[0]}'")
else:
    print("No data, or that question number does not exist. Check Step 4.")
# Out:
# Pie chart for: How would you rate your overall comfort level when using a computer or laptop?
# /tmp/ipykernel_1664/2016600697.py:16: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# Most people answered: 'I can browse the web and check email, but often need help with other tasks'

# %% [markdown]
# ## Step 8: Compare two questions (crosstab)
#
# This is where it gets interesting. A **crosstab** shows how answers to one question relate to answers to another, for example, do people who chose A on question 1 tend to choose X on question 2?
#
# We show it as a grouped bar chart, which is the honest way to compare two categorical questions.

# %%
question_a = 5   # first question
question_b = 10   # second question

if len(data) > 1 and question_a < len(df.columns) and question_b < len(df.columns):
    name_a = df.columns[question_a]
    name_b = df.columns[question_b]

    # Build the crosstab: counts of each combination
    crosstab = pd.crosstab(df.iloc[:, question_a], df.iloc[:, question_b])

    print(f"How '{name_a}' relates to '{name_b}':\n")
    display(crosstab)

    crosstab.plot(kind='bar', figsize=(12, 6))
    plt.title(f'{name_a}  vs  {name_b}', fontsize=13, fontweight='bold')
    plt.xlabel(name_a)
    plt.ylabel('Number of people')
    plt.xticks(rotation=45, ha='right')
    plt.legend(title=name_b, bbox_to_anchor=(1.02, 1), loc='upper left')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()

    print("Each group of bars is one answer to the first question.")
    print("The colors show how those people answered the second question.")
else:
    print("No data, or one of those question numbers does not exist. Check Step 4.")
# Out:
# How 'Rate your proficiency level for each of the following everyday tasks:   [Spreadsheets (Entering data, basic sorting, using simple formulas)]' relates to 'Which basic IT topic would you be most interested in learning more about?  ':
# Which basic IT topic would you be most interested in learning more about?    Data organization and spreadsheet basics (Excel/Sheets)  \
# Rate your proficiency level for each of the fol...
# High (Confident & Fast)                                                                                                      2
# Low (Struggle with this)                                                                                                     0
# Medium (Can do with effort)                                                                                                  3
#
# Which basic IT topic would you be most interested in learning more about?    Digital security, password managers, and privacy protection  \
# Rate your proficiency level for each of the fol...
# High (Confident & Fast)                                                                                                      6
# Low (Struggle with this)                                                                                                     0
# Medium (Can do with effort)                                                                                                  7
#
# Which basic IT topic would you be most interested in learning more about?    Keyboard shortcuts and operating system navigation tricks  \
# Rate your proficiency level for each of the fol...
# High (Confident & Fast)                                                                                                      3
# Low (Struggle with this)                                                                                                     1
# Medium (Can do with effort)                                                                                                  3
#
# Which basic IT topic would you be most interested in learning more about?    Understanding hardware specs (RAM, CPU, storage) when buying a PC
# Rate your proficiency level for each of the fol...
# High (Confident & Fast)                                                                                                      4
# Low (Struggle with this)                                                                                                     0
# Medium (Can do with effort)                                                                                                  3
# Each group of bars is one answer to the first question.
# The colors show how those people answered the second question.

# %% [markdown]
# ## Step 9: Full dashboard
#
# This puts a pie chart for each of your questions into one picture, a quick overview of your whole survey.

# %%
if len(data) > 1:
    question_cols = list(range(1, len(df.columns)))  # skip timestamp at column 0
    n = len(question_cols)

    cols = 3
    rows = (n + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(6*cols, 5*rows))
    fig.suptitle('Survey Results Dashboard', fontsize=16, fontweight='bold')

    axes_flat = axes.flatten() if n > 1 else [axes]

    for i, qcol in enumerate(question_cols):
        counts = df.iloc[:, qcol].value_counts()
        axes_flat[i].pie(counts.values,
                         labels=counts.index.astype(str),
                         autopct='%1.0f%%',
                         startangle=90)
        title = df.columns[qcol]
        title = title[:30] + "..." if len(title) > 30 else title
        axes_flat[i].set_title(title, fontsize=10, fontweight='bold')

    # turn off any leftover empty boxes
    for j in range(n, len(axes_flat)):
        axes_flat[j].axis('off')

    plt.tight_layout()
    plt.show()
    print(f"Dashboard created for {n} questions.")
else:
    print("No data to build a dashboard yet. Fill out your form first.")
# Out:
# /tmp/ipykernel_1664/1532176845.py:26: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()
# Dashboard created for 10 questions.

# %% [markdown]
# My Interpretation: Based on the survey dashboard, while 100% of the 32 respondents navigate Windows best, a critical confidence gap exists: 44% are restricted to basic browsing and email tasks, and 63% actively delay or ignore vital software updates due to fear of system instability. In daily tasks, web browsing and file management show the highest confidence levels at 66% and 62% respectively, whereas spreadsheets emerge as the primary operational bottleneck, with exactly 50% of users needing significant effort to navigate them. When internet connectivity fails, 56% attempt basic troubleshooting like cycling Wi-Fi, but 22% immediately call technical support. To bridge these gaps, 41% of respondents are highly motivated to learn about digital security and privacy, indicating that future IT initiatives should prioritize secure update management and practical spreadsheet workflows.

# %% [markdown]
# ---
# ### You did it!
#
# You connected live survey data to code and turned it into charts, the same thing data analysts do every day, just with bigger datasets.
#
# Mahaba pa ang pwedeng gawin dito. Kung gusto nyo ng mas malalim na breakdown, tanong lang.
#
# — eMathrix Education · Data Science & Data Analytics
